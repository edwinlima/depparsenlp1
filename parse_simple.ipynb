# %%
##############################
# import modules
##############################

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import tensorflow as tf

from gensim.models import word2vec
from gensim import models
import subprocess
# Out:
# /usr/lib/python3.4/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
# read the file, 
def read_data(filename):
    data = []
    with open(filename, 'r', encoding='utf-8') as myfile:
        f = myfile.readlines()
        s_num = 0
        i =0
        sentence_s = []
        tag_s = []
        dep_s = []
        s  = []   # sentence
        p = []    # tag
        d = []    # dependency
        for l in f:
            
            v = l.replace('\n','').split("\t")
            v.append(s_num)
            if len(l) != 1:
                data.append(v)
                dep = v[6] + '_' + v[7]
                word = v[1].lower()
                if any(char.isdigit() for char in word):
                    word = 'NUM'       # replace numbers with NUM
                s.append(word)
                p.append(v[3])
                d.append(dep)
                i +=1
            else:
                sentence_s.append(s)
                tag_s.append(p)
                dep_s.append(d)
                s_num +=1
                s  = []
                p = []
                d = []
        
    return data, sentence_s, tag_s, dep_s

# %%
def process_data(dataname):
    #reads in files, produces data structure with all actions
        #does so by applying produce_rule_list to every sentence.
        #for loop that sets actions to empty, calls p_r_l giving it
        #the stack and buffer, actions and correct_parse, adds finished action list
        #to new data file, for each sentence in the input data
    #input: name of the data file with all parses. Run with data file in same directory.
    #output: data file with all actions
    file = open(dataname)
    data = file.read()
    correct_parses = correct_parse_list(data)
    #gets rid of final whitespace
    del correct_parses[len(correct_parses)-1]
    
    #iterates over all parses, producing action list for each
    complete_rule_list = []
    arc_dict = {'Shift':0,'L_root':1,'R_root':2}
    for sentence_parse in correct_parses:
        stack = []
#         print(len(sentence_parse))
        buff = list(range(1,len(sentence_parse)+1))
        actions = []
        rule_list, arc_dict = produce_rule_list(stack, buff, actions, sentence_parse, arc_dict)
        complete_rule_list.append(np.array(rule_list))

    
    return complete_rule_list, arc_dict

def correct_parse_list(data):
    #Turns data into a list of lists of lists with relevant information
    correct_parse = data.split("\n\n")
    for index, paragraph in enumerate(correct_parse):
        correct_parse[index] = paragraph.split("\n")
    for paragraph in correct_parse:
        for index, line in enumerate(paragraph):
            paragraph[index] = line.split("\t")
    return correct_parse

# %%
def produce_rule_list(stack, buff, actions, sentence_parse, arc_dict):
    #recursive function that works through words in the sentence (stack/buffer)
        #until only one word is left, creating the list of actions 
        #that was taken to parse it.
    #input: stack, buffer, actions, correct parse
    #output: actions with the actions taken for each buff/stack configuration
    
    #base case
    if len(stack) == 1 and len(buff) == 0:
        #actions.append([stack[:], "empty", "R_arc"])
        actions.append([0,stack[0], 0, 2])
        return actions, arc_dict

    #If enough of the sentence is still left:
    #If there is not enough material in the stack, shift:
    if len(stack) == 0 :
        #print('chose S - small stack')
        actions.append([0,0,buff[0], 0])
        stack.append(buff[0])
        del buff[0]        
        return produce_rule_list(stack,buff,actions,sentence_parse, arc_dict)
    if len(stack) == 1:
        actions.append([0,stack[-1],buff[0], 0])
        stack.append(buff[0])
        del buff[0]
        return produce_rule_list(stack,buff,actions,sentence_parse, arc_dict)
    #If there are 2 or more words in the stack, decide which action to perform and perform it
    if len(stack) > 1:
        action = rule_decision(stack,buff,sentence_parse)
        stack, buff, actions, arc_dict = action(stack,buff,actions, sentence_parse, arc_dict)
        return produce_rule_list(stack,buff,actions,sentence_parse, arc_dict)
    

def rule_decision(stack, buff, sentence_parse):
    #determines which action to apply
    #input: words on stack, words on buff, correct parse
    #output: one of three methods, Shift(), L_arc(), R_arc()

    #find ids/heads (index [6]) from stack and sentence_parse
    s1 = stack[-2]
    head_of_s1 = int(sentence_parse[s1-1][6])
    s2 = stack[-1]
    head_of_s2 = int(sentence_parse[s2-1][6])
    
    #L arcs can always be applied if possible
    if head_of_s1 == s2:
        action = L_arc
        #print('chose L')
    else:
        #R arcs can only be applied if there is no word in the buffer which has the last word in the stack as a head
        if head_of_s2 == s1:
            buff_heads = [int(sentence_parse[x-1][6]) for x in buff]
            if s2 in buff_heads:
                action = Shift
                #print('chose S - s2 in buffheads')
            else:
                action = R_arc
                #print('chose R')
        #if there is no match between s1 and s2, simply shift another word from the buffer
        else:
            action = Shift
            #print('chose S - no matching s1s2')

    return action

#The following methods perform an arc or shift. These can be changed if more data is needed in the network.

def L_arc(stack, buff, actions, sentence_parse, arc_dict):
    #removes second to last item from stack, writes action to actions
    #input: stack and actions
    #output: new stack and actions with one L_arc line
    #s1, s2, b1, action
    s1 = int(stack[-2])
    s2 = int(stack[-1])
    if len(buff) == 0:
        b1 = 0
    else:
        b1 = int(buff[0])
    relation = "L_"+sentence_parse[s1-1][7]

    if relation not in arc_dict:
        maximum = max(arc_dict, key=arc_dict.get)
        arc_dict['L_'+relation[2:]] = arc_dict[maximum]+1
        arc_dict['R_'+relation[2:]] = arc_dict[maximum]+2
    

    actions.append([s1,s2,b1, arc_dict[relation]])
    del stack[-2]
    return stack, buff, actions, arc_dict



def R_arc(stack, buff, actions, sentence_parse, arc_dict):
    #removes last item from the stack, writes action to actions
    #input: stack and actions
    #output: new stack and actions with one R_arc line
    #s1, s2, b1, action
    s1 = int(stack[-2])
    s2 = int(stack[-1])
    if len(buff) == 0:
        b1 = 0
    else:
        b1 = int(buff[0])
        
    relation = "R_"+sentence_parse[s2-1][7]

    if relation not in arc_dict:
        maximum = max(arc_dict, key=arc_dict.get)
        arc_dict['L_'+relation[2:]] = arc_dict[maximum]+1
        arc_dict['R_'+relation[2:]] = arc_dict[maximum]+2 
    
    actions.append([s1,s2,b1, arc_dict[relation]])
    del stack[-1]
    return stack, buff, actions, arc_dict



def Shift(stack, buff, actions, sentence_parse, arc_dict):
    #moves an item from the buff to the stack, writes action to actions
    #input: stack, buff and actions
    #output: new stack and actions with one extra shift line
    #s1, s2, b1, action
    s1 = int(stack[-2])
    s2 = int(stack[-1])
    b1 = int(buff[0])
    #actions.append([stack[:], buff[:], "Shift"])
    actions.append([s1,s2,b1, 0])
    stack.append(buff[0])
    del buff[0]
    return stack, buff, actions, arc_dict

# %%
train_data, train_sentences, train_tags, train_dependencies = read_data('./data/train-stanford-raw.conll')
dev_data, dev_sentences, dev_tags, dev_dependencies = read_data('./data/dev-stanford-raw.conll')
test_data, test_sentences, test_tags, test_dependencies = read_data('./data/test-stanford-raw.conll')

# create a full set of all the words in our train, test, and dev sets for word2vec model
# in order to avoid unseen words during test and validation
total_sentences = train_sentences + dev_sentences + test_sentences
print('data: ', train_data[:2])
print('words sentences: ', total_sentences[2:4])
print('tags sentences: ', train_tags[2:4])
print('dependencies: ', train_dependencies[2:4])
# Out:
# data:  [['1', 'In', '_', 'IN', 'IN', '_', '45', 'prep', '_', '_', 0], ['2', 'an', '_', 'DT', 'DT', '_', '5', 'det', '_', '_', 0]]
# words sentences:  [['rolls-royce', 'motor', 'cars', 'inc.', 'said', 'it', 'expects', 'its', 'u.s.', 'sales', 'to', 'remain', 'steady', 'at', 'about', 'NUM', 'cars', 'in', 'NUM', '.'], ['the', 'luxury', 'auto', 'maker', 'last', 'year', 'sold', 'NUM', 'cars', 'in', 'the', 'u.s.']]
# tags sentences:  [['NNP', 'NNP', 'NNPS', 'NNP', 'VBD', 'PRP', 'VBZ', 'PRP$', 'NNP', 'NNS', 'TO', 'VB', 'JJ', 'IN', 'IN', 'CD', 'NNS', 'IN', 'CD', '.'], ['DT', 'NN', 'NN', 'NN', 'JJ', 'NN', 'VBD', 'CD', 'NNS', 'IN', 'DT', 'NNP']]
# dependencies:  [['4_nn', '4_nn', '4_nn', '5_nsubj', '0_root', '7_nsubj', '5_ccomp', '10_poss', '10_nn', '12_nsubj', '12_aux', '7_xcomp', '12_acomp', '12_prep', '16_quantmod', '17_num', '14_pobj', '12_prep', '18_pobj', '5_punct'], ['4_det', '4_nn', '4_nn', '7_nsubj', '6_amod', '7_tmod', '0_root', '9_num', '7_dobj', '7_prep', '12_det', '10_pobj']]

# %%
action_data, arc_dict = process_data('./data/train-stanford-raw.conll')

# %%
###############################################
# Interactive parser and evaluation functions #
###############################################

def sentences_to_conll(sentences, arc_dict, file_name):
    action_dict = {v:k for k,v in arc_dict.items()}
    all_sentences_listed = []
    for sentence in sentences:
        sentence_parse = [[i+1,word,'_','_','_','_','_','_','_','_'] 
                          for i, word in enumerate(sentence)]
        w2v_matrix = create_sentence_embeddings([sentence])[0]
        stack = []
        buff = list(range(1,len(sentence)+1))
        sentence_parse = single_sentence_parse(stack, buff, sentence_parse, action_dict, w2v_matrix)
        all_sentences_listed.append(sentence_parse)
    convert_to_conll(all_sentences_listed, file_name)        
    return

def single_sentence_parse(stack, buff, sentence_parse, action_dict, w2v_matrix):
    #If there are 2 or more words in the stack, decide which action to perform and perform it
    if len(stack) > 1:
        s1 = int(stack[-2])
        s2 = int(stack[-1])
        #checks whether buffer contains words
        if len(buff) > 0:
            b1 = int(buff[0])
            action = model_action_decision(w2v_matrix,s1,s2,b1,False)
        else:
            b1 = 0
            action = model_action_decision(w2v_matrix,s1,s2,b1,True)
        
        if action == 0:
            # perform a shift
            stack, buff = Shift(stack, buff)
        elif action%2 == 1:
            # left-arc. All left tags are odd in the dictionary
            stack, sentence_parse = L_arc(stack,s1,s2, sentence_parse, action_dict, action)
        else:
            # right-arc. All right tags are even in the dictionary
            stack, sentence_parse = R_arc(stack,s1,s2, sentence_parse, action_dict, action)
        return single_sentence_parse(stack, buff, sentence_parse, action_dict, w2v_matrix)
    
    #base case (R_arc): if only one word is left, perform the last right arc with root.
    if len(stack) == 1 and len(buff) == 0:
        sentence_parse[stack[0]-1][6] = 0
        sentence_parse[stack[0]-1][7] = 'root'
        return sentence_parse    

    #If there is not enough material in the stack, shift:
    if len(stack) == 0 :
        #print('chose S - small stack')
        stack, buff = Shift(stack, buff)       
        return single_sentence_parse(stack, buff, sentence_parse, action_dict, w2v_matrix)
    if len(stack) == 1:
        stack, buff = Shift(stack, buff)
        return single_sentence_parse(stack, buff, sentence_parse, action_dict, w2v_matrix)
    
def model_action_decision(w2v_matrix,s1,s2,b1,emptybuffer):
    #if emptybuffer is true, exclude option 0 (shift).
    pred_input = {sentence_length: [len(w2v_matrix)], 
                  lstm_x: [w2v_matrix],  parse_indices: 
                  [np.array([[s1,s2,b1]])]} # feed_dict without labels
    prediction = session.run(output_mlp, pred_input)[0]
    if emptybuffer == False:
        action = np.argmax(prediction)
    else:
        pred = np.delete(prediction,[0])
        action = np.argmax(pred)+1
    return action
        
    
def L_arc(stack,s1,s2, sentence_parse, action_dict, action):
    #removes second to last item from stack, sends info to sentence_parse

    action_type = action_dict[action]
    
    #update head and relation for s1
    sentence_parse[s1-1][6] = s2
    sentence_parse[s1-1][7] = action_type[2:]
    
    del stack[-2]
    return stack, sentence_parse


def R_arc(stack,s1,s2, sentence_parse, action_dict, action):
    #removes last item from the stack, sends info to sentence_parse
    
    action_type = action_dict[action]

    #update head and relation for s2
    sentence_parse[s2-1][6] = s1
    sentence_parse[s2-1][7] = action_type[2:]
    
    del stack[-1]
    return stack, sentence_parse


def Shift(stack, buff):
    #moves an item from the buff to the stack
    #input: stack, buff
    #output: new stack and buff
    stack.append(buff[0])
    del buff[0]
    return stack, buff

def convert_to_conll(sentences, file_name):
    content = "\n\n".join(["\n".join(["\t".join([str(var) 
                                                 for var in word]) 
                                      for word in sentence]) 
                           for sentence in sentences]) + "\n"
    with open(file_name+".conll", "w") as text_file:
        text_file.write(content)

# %%
##############################
# TF functions
##############################

def mlp(_X, _weights, _biases):
    """
    function that defines a multilayer perceptron in the graph
    input shape: parse_steps (=?) x filtered_words (=3) x lstm_output_length (=400)
    output shape: parse_steps (=?) x num_classes
    """
    # ReLU hidden layer (output shape: parse_steps x n_hidden)
    layer_1 = tf.nn.relu(tf.add(tf.matmul(_X, _weights['h']), _biases['b'])) 
    # return output layer (output shape: parse_steps x n_classes)
    return tf.add(tf.matmul(layer_1, _weights['out']), _biases['out'])


def create_sentence_embeddings(sentences):
    """
    for each sentence, get embedded representation
    """
    embedded_train_sentences = []
    for sentence in sentences:
        embed = model[sentence]
        embedded_train_sentences.append(embed)
    return embedded_train_sentences

# %%
##############################
# load word2vec model & input data
##############################

model_name = "dep_parser_word2vec_total"
model = word2vec.Word2Vec.load(model_name)

# embeddings for all sentences
sentence_embeddings = create_sentence_embeddings(train_sentences)

# %%
##############################
# TensorFlow model
##############################

graph = tf.Graph()
with graph.as_default():
        
    # hyperparameters (from Cross & Huang, 2016)
    word2vec_length = model['a'].size
    n_input = 400
    n_hidden = 200
    n_classes = 99 # there are 99 possible actions to take
    lstm_units = 200
    num_epochs = 10 # at least 1 for now
    dropout = 0.5
    L2_penalty = 0.
    rho = 0.99
    epsilon = 1e-07
    learning_rate = 0.02 # default is 0.001, Cross & Huang do not specify learning rate

    # Store layers weight & bias
    weights = {
        'h': tf.Variable(tf.random_normal([3*n_input, n_hidden], dtype=tf.float64), name='weights_h'),
        'out': tf.Variable(tf.random_normal([n_hidden, n_classes], dtype=tf.float64), name='weights_out')
    }
    biases = {
        'b': tf.Variable(tf.random_normal([n_hidden], dtype=tf.float64), name='biases_b'),
        'out': tf.Variable(tf.random_normal([n_classes], dtype=tf.float64), name='biases_out')
    }
    
    # placeholders
    sentence_length = tf.placeholder(tf.int32)
    lstm_x = tf.placeholder(tf.float64, [1, None, word2vec_length])
    parse_indices = tf.placeholder(tf.int64, [1, None, 3])
    labels = tf.placeholder(tf.int64, [None])
    
    # define LSTM cell + dropout wrapper (like Cross & Huang)
    cell = tf.nn.rnn_cell.BasicLSTMCell(num_units=lstm_units, state_is_tuple=True)
    cell = tf.nn.rnn_cell.DropoutWrapper(cell=cell, output_keep_prob=dropout)

    # define bidirectional architecture
    outputs, _ = tf.nn.bidirectional_dynamic_rnn(
        cell_fw=cell,
        cell_bw=cell,
        dtype=tf.float64,
        sequence_length=sentence_length,
        inputs=lstm_x
    )

    # fw/bw output
    output_fw, output_bw = outputs

    # concatenate forward & backward outputs per word
    output_lstm = tf.concat(2, outputs)
    
    # zero-padding of LSTM-output (sentence gets a "dummy word" in front of it)
    zero_padding = tf.zeros([1, 1, n_input], tf.float64)
    output_lstm = tf.concat(1, [zero_padding, output_lstm])
   
    # mlp_x: make a matrix with all corresponding word vector 3-tuples, CONCATENATED (up to the no of parse steps)
    mlp_x = tf.nn.embedding_lookup(output_lstm[0,:,:], parse_indices[0,:,:])
    dims = tf.shape(mlp_x)
    mlp_x = tf.reshape(mlp_x, [dims[0], dims[1]*dims[2]])

    output_mlp = mlp(mlp_x, weights, biases)

    cost = tf.reduce_sum(tf.nn.sparse_softmax_cross_entropy_with_logits(output_mlp, labels))
    cost_indication = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(output_mlp, labels))

    train_op = tf.train.AdadeltaOptimizer(rho=rho, epsilon=epsilon, learning_rate=learning_rate).minimize(cost)
    
    # TODO: tf.train.Saver(...variables...)
    saver = tf.train.Saver()
    
    with tf.Session() as session:
        init = tf.initialize_all_variables()
        session.run(init)
        
        for epoch in range(0,num_epochs): # num_epochs is now 1
            for i in range(0,len(sentence_embeddings)): # should be range(0,len(sentence_embeddings)) 
                
                # get sentence embedding
                sentence = sentence_embeddings[i]
                
                # get parse data for sentence
                parse_data = action_data[i]
                
                indices = parse_data[:,:3]
                actions = parse_data[:,3]
                
                # important variables
                seq_length = len(sentence)
                                
                feed_dict_batch = {sentence_length: [seq_length], lstm_x: [sentence],  parse_indices: [indices], labels: actions}
                
                result = session.run([train_op, cost_indication], feed_dict_batch)
                
                if i%250 == 0:
                    print("epoch ", epoch, ", iteration ", i, "\n", "current average loss: ", result[1])
                
                if i%2500 == 0:
                    print("evaluating..")
                    # TODO: prediction on validation set every 200 sentences
                    # TODO: sentences_to_conll() gives error after 150/200 iterations!
                    # TODO: do the unlabeled attachment scores make sense?
                    sentences_to_conll(train_sentences[:10], arc_dict, "HALLO_"+str(i))
                    val_output = subprocess.check_output(["perl", "eval.pl", "-g", "HOI.conll", "-s", "HALLO_"+str(i)+".conll", "-q"])
                    print(val_output.decode("utf-8"))
                
                if i%5000 == 0:
                    name = "tf_models/model-" + str(epoch) + "-" + str(i)
                    print("saving model with name " + name)
                    saver.save(session, name)
# Out:
# /usr/lib/python3.4/site-packages/tensorflow/python/ops/gradients.py:90: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# epoch  0 , iteration  0
#  current average loss:  192.472604952
# evaluating..
#   Labeled   attachment score: 0 / 167 * 100 = 0.00 %
#   Unlabeled attachment score: 24 / 167 * 100 = 14.37 %
#   Label accuracy score:       4 / 167 * 100 = 2.40 %
#
# saving model with name tf_models/model-0-0
# epoch  0 , iteration  250
#  current average loss:  71.6728517037
# epoch  0 , iteration  500
#  current average loss:  43.5570681557
# epoch  0 , iteration  750
#  current average loss:  35.132597085
# epoch  0 , iteration  1000
#  current average loss:  33.9466825075
# epoch  0 , iteration  1250
#  current average loss:  32.5155075917
# epoch  0 , iteration  1500
#  current average loss:  34.1868541021
# epoch  0 , iteration  1750
#  current average loss:  25.6780457762
# epoch  0 , iteration  2000
#  current average loss:  22.1166931433
# epoch  0 , iteration  2250
#  current average loss:  30.0089511594
# epoch  0 , iteration  2500
#  current average loss:  21.8941934197
# evaluating..
#   Labeled   attachment score: 8 / 167 * 100 = 4.79 %
#   Unlabeled attachment score: 31 / 167 * 100 = 18.56 %
#   Label accuracy score:       19 / 167 * 100 = 11.38 %
#
# epoch  0 , iteration  2750
#  current average loss:  17.6390035695
# epoch  0 , iteration  3000
#  current average loss:  16.0937881755
# epoch  0 , iteration  3250
#  current average loss:  18.0306749278
# epoch  0 , iteration  3500
#  current average loss:  17.2126937817
# epoch  0 , iteration  3750
#  current average loss:  12.6018105746
# epoch  0 , iteration  4000
#  current average loss:  16.1260464442
# epoch  0 , iteration  4250
#  current average loss:  18.1202597829
# epoch  0 , iteration  4500
#  current average loss:  11.7488651267
# epoch  0 , iteration  4750
#  current average loss:  7.96159330609
# epoch  0 , iteration  5000
#  current average loss:  8.35195891669
# evaluating..
#   Labeled   attachment score: 13 / 167 * 100 = 7.78 %
#   Unlabeled attachment score: 29 / 167 * 100 = 17.37 %
#   Label accuracy score:       29 / 167 * 100 = 17.37 %
#
# saving model with name tf_models/model-0-5000
# epoch  0 , iteration  5250
#  current average loss:  9.51185476652
# epoch  0 , iteration  5500
#  current average loss:  7.71895518043
# epoch  0 , iteration  5750
#  current average loss:  9.25804595541
# epoch  0 , iteration  6000
#  current average loss:  8.63557921392
# epoch  0 , iteration  6250
#  current average loss:  9.20291848832
# epoch  0 , iteration  6500
#  current average loss:  7.18894514353
# epoch  0 , iteration  6750
#  current average loss:  5.64157828286
# epoch  0 , iteration  7000
#  current average loss:  9.03249852435
# epoch  0 , iteration  7250
#  current average loss:  8.45122968806
# epoch  0 , iteration  7500
#  current average loss:  3.73776458335
# evaluating..
#   Labeled   attachment score: 18 / 167 * 100 = 10.78 %
#   Unlabeled attachment score: 41 / 167 * 100 = 24.55 %
#   Label accuracy score:       34 / 167 * 100 = 20.36 %
#
# epoch  0 , iteration  7750
#  current average loss:  8.34745192302
# epoch  0 , iteration  8000
#  current average loss:  3.99196488113
# epoch  0 , iteration  8250
#  current average loss:  3.8048313706
# epoch  0 , iteration  8500
#  current average loss:  4.96809822005
# epoch  0 , iteration  8750
#  current average loss:  5.23976605153
# epoch  0 , iteration  9000
#  current average loss:  4.44493792192
# epoch  0 , iteration  9250
#  current average loss:  3.69106220688
# epoch  0 , iteration  9500
#  current average loss:  5.47544298911
# epoch  0 , iteration  9750
#  current average loss:  3.37346526065
# epoch  0 , iteration  10000
#  current average loss:  3.27167336445
# evaluating..
#   Labeled   attachment score: 25 / 167 * 100 = 14.97 %
#   Unlabeled attachment score: 51 / 167 * 100 = 30.54 %
#   Label accuracy score:       45 / 167 * 100 = 26.95 %
#
# saving model with name tf_models/model-0-10000
# epoch  0 , iteration  10250
#  current average loss:  3.78714444822
# epoch  0 , iteration  10500
#  current average loss:  5.30748532815
# epoch  0 , iteration  10750
#  current average loss:  2.9466513841
# epoch  0 , iteration  11000
#  current average loss:  3.76117265083
# epoch  0 , iteration  11250
#  current average loss:  2.65722707474
# epoch  0 , iteration  11500
#  current average loss:  3.38352818236
# epoch  0 , iteration  11750
#  current average loss:  2.36955263031
# epoch  0 , iteration  12000
#  current average loss:  3.86456636238
# epoch  0 , iteration  12250
#  current average loss:  3.97212276025
# epoch  0 , iteration  12500
#  current average loss:  3.43742703828
# evaluating..
#   Labeled   attachment score: 29 / 167 * 100 = 17.37 %
#   Unlabeled attachment score: 51 / 167 * 100 = 30.54 %
#   Label accuracy score:       57 / 167 * 100 = 34.13 %
#
# epoch  0 , iteration  12750
#  current average loss:  3.29268297119
# epoch  0 , iteration  13000
#  current average loss:  0.869555072811
# epoch  0 , iteration  13250
#  current average loss:  2.96188184154
# epoch  0 , iteration  13500
#  current average loss:  4.38684786811
# epoch  0 , iteration  13750
#  current average loss:  2.7045525961
# epoch  0 , iteration  14000
#  current average loss:  3.7067232797
# epoch  0 , iteration  14250
#  current average loss:  3.22324815306
# epoch  0 , iteration  14500
#  current average loss:  3.49935587566
# epoch  0 , iteration  14750
#  current average loss:  1.44520974631
# epoch  0 , iteration  15000
#  current average loss:  3.15533145172
# evaluating..
#   Labeled   attachment score: 37 / 167 * 100 = 22.16 %
#   Unlabeled attachment score: 55 / 167 * 100 = 32.93 %
#   Label accuracy score:       55 / 167 * 100 = 32.93 %
#
# saving model with name tf_models/model-0-15000
# epoch  0 , iteration  15250
#  current average loss:  3.18669849948
# epoch  0 , iteration  15500
#  current average loss:  3.43868188855
# epoch  0 , iteration  15750
#  current average loss:  2.60314795694
# epoch  0 , iteration  16000
#  current average loss:  1.7257066968
# epoch  0 , iteration  16250
#  current average loss:  2.02416400755
# epoch  0 , iteration  16500
#  current average loss:  2.36099107233
# epoch  0 , iteration  16750
#  current average loss:  1.94292863348
# epoch  0 , iteration  17000
#  current average loss:  1.57334321839
# epoch  0 , iteration  17250
#  current average loss:  1.82938909682
# epoch  0 , iteration  17500
#  current average loss:  1.50701275282
# evaluating..
#   Labeled   attachment score: 40 / 167 * 100 = 23.95 %
#   Unlabeled attachment score: 59 / 167 * 100 = 35.33 %
#   Label accuracy score:       60 / 167 * 100 = 35.93 %
#
# epoch  0 , iteration  17750
#  current average loss:  2.5039095355
# epoch  0 , iteration  18000
#  current average loss:  1.14139059742
# epoch  0 , iteration  18250
#  current average loss:  1.97048811108
# epoch  0 , iteration  18500
#  current average loss:  2.44301720089
# epoch  0 , iteration  18750
#  current average loss:  2.01250756335
# epoch  0 , iteration  19000
#  current average loss:  3.19506923242
# epoch  0 , iteration  19250
#  current average loss:  1.37887069317
# epoch  0 , iteration  19500
#  current average loss:  3.24162752828
# epoch  0 , iteration  19750
#  current average loss:  2.12611761245
# epoch  0 , iteration  20000
#  current average loss:  0.946903017842
# evaluating..
#   Labeled   attachment score: 47 / 167 * 100 = 28.14 %
#   Unlabeled attachment score: 71 / 167 * 100 = 42.51 %
#   Label accuracy score:       69 / 167 * 100 = 41.32 %
#
# saving model with name tf_models/model-0-20000
# epoch  0 , iteration  20250
#  current average loss:  2.11719746918
# epoch  0 , iteration  20500
#  current average loss:  1.46224454025
# epoch  0 , iteration  20750
#  current average loss:  1.75077981268
# epoch  0 , iteration  21000
#  current average loss:  1.75396847333
# epoch  0 , iteration  21250
#  current average loss:  2.1718159568
# epoch  0 , iteration  21500
#  current average loss:  1.09275989468
# epoch  0 , iteration  21750
#  current average loss:  1.661583074
# epoch  0 , iteration  22000
#  current average loss:  1.96916591744
# epoch  0 , iteration  22250
#  current average loss:  2.50697876365
# epoch  0 , iteration  22500
#  current average loss:  1.26808940465
# evaluating..
#   Labeled   attachment score: 53 / 167 * 100 = 31.74 %
#   Unlabeled attachment score: 78 / 167 * 100 = 46.71 %
#   Label accuracy score:       78 / 167 * 100 = 46.71 %
#
# epoch  0 , iteration  22750
#  current average loss:  1.73120721318
# epoch  0 , iteration  23000
#  current average loss:  1.64831414191
# epoch  0 , iteration  23250
#  current average loss:  1.23868909229
# epoch  0 , iteration  23500
#  current average loss:  2.03582450089
# epoch  0 , iteration  23750
#  current average loss:  1.83620596521
# epoch  0 , iteration  24000
#  current average loss:  1.68825874922
# epoch  0 , iteration  24250
#  current average loss:  0.822610175557
# epoch  0 , iteration  24500
#  current average loss:  0.484398367151
# epoch  0 , iteration  24750
#  current average loss:  2.122365495
# epoch  0 , iteration  25000
#  current average loss:  1.60780674827
# evaluating..
#   Labeled   attachment score: 53 / 167 * 100 = 31.74 %
#   Unlabeled attachment score: 68 / 167 * 100 = 40.72 %
#   Label accuracy score:       73 / 167 * 100 = 43.71 %
#
# saving model with name tf_models/model-0-25000
# epoch  0 , iteration  25250
#  current average loss:  1.44781314454
# epoch  0 , iteration  25500
#  current average loss:  1.32519326072
# epoch  0 , iteration  25750
#  current average loss:  1.36713428813
# epoch  0 , iteration  26000
#  current average loss:  2.35835420471
# epoch  0 , iteration  26250
#  current average loss:  1.45689806509
# epoch  0 , iteration  26500
#  current average loss:  1.26000926829
# epoch  0 , iteration  26750
#  current average loss:  1.41786344154
# epoch  0 , iteration  27000
#  current average loss:  1.9794504453
# epoch  0 , iteration  27250
#  current average loss:  0.443884834919
# epoch  0 , iteration  27500
#  current average loss:  1.64183297913
# evaluating..
#   Labeled   attachment score: 44 / 167 * 100 = 26.35 %
#   Unlabeled attachment score: 61 / 167 * 100 = 36.53 %
#   Label accuracy score:       80 / 167 * 100 = 47.90 %
#
# epoch  0 , iteration  27750
#  current average loss:  1.03165535354
# epoch  0 , iteration  28000
#  current average loss:  1.92965894971
# epoch  0 , iteration  28250
#  current average loss:  1.85329002602
# epoch  0 , iteration  28500
#  current average loss:  1.02659589539
# epoch  0 , iteration  28750
#  current average loss:  2.05968937609
# epoch  0 , iteration  29000
#  current average loss:  2.03795354473
# epoch  0 , iteration  29250
#  current average loss:  1.94499532544
# epoch  0 , iteration  29500
#  current average loss:  0.816385639508
# epoch  0 , iteration  29750
#  current average loss:  0.955319529158
# epoch  0 , iteration  30000
#  current average loss:  1.00619232892
# evaluating..
#   Labeled   attachment score: 60 / 167 * 100 = 35.93 %
#   Unlabeled attachment score: 78 / 167 * 100 = 46.71 %
#   Label accuracy score:       88 / 167 * 100 = 52.69 %
#
# saving model with name tf_models/model-0-30000
# epoch  0 , iteration  30250
#  current average loss:  1.41736664002
# epoch  0 , iteration  30500
#  current average loss:  1.83036028381
# epoch  0 , iteration  30750
#  current average loss:  0.968731493878
# epoch  0 , iteration  31000
#  current average loss:  0.808463963153
# epoch  0 , iteration  31250
#  current average loss:  1.7047691099
# epoch  0 , iteration  31500
#  current average loss:  0.986767318375
# epoch  0 , iteration  31750
#  current average loss:  0.680116370432
# epoch  0 , iteration  32000
#  current average loss:  1.6362615538
# epoch  0 , iteration  32250
#  current average loss:  1.19164627407
# epoch  0 , iteration  32500
#  current average loss:  1.06523484108
# evaluating..
#   Labeled   attachment score: 60 / 167 * 100 = 35.93 %
#   Unlabeled attachment score: 80 / 167 * 100 = 47.90 %
#   Label accuracy score:       84 / 167 * 100 = 50.30 %
#
# epoch  0 , iteration  32750
#  current average loss:  1.45968994516
# epoch  0 , iteration  33000
#  current average loss:  1.41006956487
# epoch  0 , iteration  33250
#  current average loss:  1.71243834218
# epoch  0 , iteration  33500
#  current average loss:  0.824299413346
# epoch  0 , iteration  33750
#  current average loss:  1.42032581098
# epoch  0 , iteration  34000
#  current average loss:  1.24930763186
# epoch  0 , iteration  34250
#  current average loss:  1.16744871281
# epoch  0 , iteration  34500
#  current average loss:  1.14493629911
# epoch  0 , iteration  34750
#  current average loss:  1.36222353099
# epoch  0 , iteration  35000
#  current average loss:  1.47663033652
# evaluating..
#   Labeled   attachment score: 58 / 167 * 100 = 34.73 %
#   Unlabeled attachment score: 74 / 167 * 100 = 44.31 %
#   Label accuracy score:       90 / 167 * 100 = 53.89 %
#
# saving model with name tf_models/model-0-35000
# epoch  0 , iteration  35250
#  current average loss:  1.68175749763
# epoch  0 , iteration  35500
#  current average loss:  1.47831166678
# epoch  0 , iteration  35750
#  current average loss:  2.58533839243
# epoch  0 , iteration  36000
#  current average loss:  1.10102088666
# epoch  0 , iteration  36250
#  current average loss:  0.863581657586
# epoch  0 , iteration  36500
#  current average loss:  1.06078650991
# epoch  0 , iteration  36750
#  current average loss:  1.45907853088
# epoch  0 , iteration  37000
#  current average loss:  1.15299341827
# epoch  0 , iteration  37250
#  current average loss:  1.25923270945
# epoch  0 , iteration  37500
#  current average loss:  2.27374595457
# evaluating..
#   Labeled   attachment score: 73 / 167 * 100 = 43.71 %
#   Unlabeled attachment score: 80 / 167 * 100 = 47.90 %
#   Label accuracy score:       94 / 167 * 100 = 56.29 %
#
# epoch  0 , iteration  37750
#  current average loss:  1.18864224515
# epoch  0 , iteration  38000
#  current average loss:  1.53837840388
# epoch  0 , iteration  38250
#  current average loss:  1.32509395546
# epoch  0 , iteration  38500
#  current average loss:  0.445170053852
# epoch  0 , iteration  38750
#  current average loss:  0.847852773327
# epoch  0 , iteration  39000
#  current average loss:  1.47972084204
# epoch  0 , iteration  39250
#  current average loss:  0.865235095641
# epoch  0 , iteration  39500
#  current average loss:  0.630535136267
# epoch  0 , iteration  39750
#  current average loss:  0.872879741919
# epoch  1 , iteration  0
#  current average loss:  1.19549858808
# evaluating..
#   Labeled   attachment score: 69 / 167 * 100 = 41.32 %
#   Unlabeled attachment score: 80 / 167 * 100 = 47.90 %
#   Label accuracy score:       94 / 167 * 100 = 56.29 %
#
# saving model with name tf_models/model-1-0
# epoch  1 , iteration  250
#  current average loss:  1.39564564175
# epoch  1 , iteration  500
#  current average loss:  1.21193919882
# epoch  1 , iteration  750
#  current average loss:  1.00239862331
# epoch  1 , iteration  1000
#  current average loss:  1.23639705913
# epoch  1 , iteration  1250
#  current average loss:  1.10732163039
# epoch  1 , iteration  1500
#  current average loss:  0.97108143118
# epoch  1 , iteration  1750
#  current average loss:  0.910186799375
# epoch  1 , iteration  2000
#  current average loss:  1.81836730325
# epoch  1 , iteration  2250
#  current average loss:  1.02452499183
# epoch  1 , iteration  2500
#  current average loss:  1.55304172349
# evaluating..
#   Labeled   attachment score: 72 / 167 * 100 = 43.11 %
#   Unlabeled attachment score: 87 / 167 * 100 = 52.10 %
#   Label accuracy score:       98 / 167 * 100 = 58.68 %
#
# epoch  1 , iteration  2750
#  current average loss:  1.47481183019
# epoch  1 , iteration  3000
#  current average loss:  1.07895778368
# epoch  1 , iteration  3250
#  current average loss:  0.954039414448
# epoch  1 , iteration  3500
#  current average loss:  1.21264931204
# epoch  1 , iteration  3750
#  current average loss:  1.82079498899
# epoch  1 , iteration  4000
#  current average loss:  1.22333788884
# epoch  1 , iteration  4250
#  current average loss:  1.84978494895
# epoch  1 , iteration  4500
#  current average loss:  1.00310215332
# epoch  1 , iteration  4750
#  current average loss:  1.12308537497
# epoch  1 , iteration  5000
#  current average loss:  0.997817486946
# evaluating..
#   Labeled   attachment score: 64 / 167 * 100 = 38.32 %
#   Unlabeled attachment score: 76 / 167 * 100 = 45.51 %
#   Label accuracy score:       92 / 167 * 100 = 55.09 %
#
# saving model with name tf_models/model-1-5000
# epoch  1 , iteration  5250
#  current average loss:  0.854284102114
# epoch  1 , iteration  5500
#  current average loss:  1.23794620349
# epoch  1 , iteration  5750
#  current average loss:  1.09058563827
# epoch  1 , iteration  6000
#  current average loss:  0.823467481507
# epoch  1 , iteration  6250
#  current average loss:  1.34844870466
# epoch  1 , iteration  6500
#  current average loss:  0.558141463991
# epoch  1 , iteration  6750
#  current average loss:  1.01525762528
# epoch  1 , iteration  7000
#  current average loss:  1.53459112129
# epoch  1 , iteration  7250
#  current average loss:  1.44488064375
# epoch  1 , iteration  7500
#  current average loss:  0.870776719231
# evaluating..
#   Labeled   attachment score: 83 / 167 * 100 = 49.70 %
#   Unlabeled attachment score: 102 / 167 * 100 = 61.08 %
#   Label accuracy score:       105 / 167 * 100 = 62.87 %
#
# epoch  1 , iteration  7750
#  current average loss:  1.74636549422
# epoch  1 , iteration  8000
#  current average loss:  0.636645000883
# epoch  1 , iteration  8250
#  current average loss:  0.731790605397
# epoch  1 , iteration  8500
#  current average loss:  1.66455789611
# epoch  1 , iteration  8750
#  current average loss:  0.569117494423
# epoch  1 , iteration  9000
#  current average loss:  0.381315118156
# epoch  1 , iteration  9250
#  current average loss:  0.904813092493
# epoch  1 , iteration  9500
#  current average loss:  1.31990174966
# epoch  1 , iteration  9750
#  current average loss:  0.504439276712
# epoch  1 , iteration  10000
#  current average loss:  0.518755279182
# evaluating..
#   Labeled   attachment score: 75 / 167 * 100 = 44.91 %
#   Unlabeled attachment score: 89 / 167 * 100 = 53.29 %
#   Label accuracy score:       103 / 167 * 100 = 61.68 %
#
# saving model with name tf_models/model-1-10000
# epoch  1 , iteration  10250
#  current average loss:  1.04882825661
# epoch  1 , iteration  10500
#  current average loss:  1.07392615869
# epoch  1 , iteration  10750
#  current average loss:  0.818534819431
# epoch  1 , iteration  11000
#  current average loss:  1.28181794144
# epoch  1 , iteration  11250
#  current average loss:  0.545300011822
# epoch  1 , iteration  11500
#  current average loss:  0.770879053627
# epoch  1 , iteration  11750
#  current average loss:  0.928214352025
# epoch  1 , iteration  12000
#  current average loss:  0.612487412754
# epoch  1 , iteration  12250
#  current average loss:  0.919342203046
# epoch  1 , iteration  12500
#  current average loss:  0.547062466747
# evaluating..
#   Labeled   attachment score: 83 / 167 * 100 = 49.70 %
#   Unlabeled attachment score: 98 / 167 * 100 = 58.68 %
#   Label accuracy score:       110 / 167 * 100 = 65.87 %
#
# epoch  1 , iteration  12750
#  current average loss:  1.07499265218
# epoch  1 , iteration  13000
#  current average loss:  0.291377871781
# epoch  1 , iteration  13250
#  current average loss:  1.09309932902
# epoch  1 , iteration  13500
#  current average loss:  0.959100888638
# epoch  1 , iteration  13750
#  current average loss:  0.786414814376
# epoch  1 , iteration  14000
#  current average loss:  1.58801039007
# epoch  1 , iteration  14250
#  current average loss:  1.34903062697
# epoch  1 , iteration  14500
#  current average loss:  1.21536741016
# epoch  1 , iteration  14750
#  current average loss:  0.441236576586
# epoch  1 , iteration  15000
#  current average loss:  1.72474852164
# evaluating..
#   Labeled   attachment score: 76 / 167 * 100 = 45.51 %
#   Unlabeled attachment score: 96 / 167 * 100 = 57.49 %
#   Label accuracy score:       101 / 167 * 100 = 60.48 %
#
# saving model with name tf_models/model-1-15000
# epoch  1 , iteration  15250
#  current average loss:  1.05342809303
# epoch  1 , iteration  15500
#  current average loss:  1.1644592992
# epoch  1 , iteration  15750
#  current average loss:  1.03174983261
# epoch  1 , iteration  16000
#  current average loss:  0.633060860572
# epoch  1 , iteration  16250
#  current average loss:  0.889677989691
# epoch  1 , iteration  16500
#  current average loss:  1.54095685927
# epoch  1 , iteration  16750
#  current average loss:  1.2225004963
# epoch  1 , iteration  17000
#  current average loss:  0.641906165977
# epoch  1 , iteration  17250
#  current average loss:  0.779560297033
# epoch  1 , iteration  17500
#  current average loss:  0.887585533379
# evaluating..
#   Labeled   attachment score: 80 / 167 * 100 = 47.90 %
#   Unlabeled attachment score: 93 / 167 * 100 = 55.69 %
#   Label accuracy score:       103 / 167 * 100 = 61.68 %
#
# epoch  1 , iteration  17750
#  current average loss:  1.19539196832
# epoch  1 , iteration  18000
#  current average loss:  0.61380325587
# epoch  1 , iteration  18250
#  current average loss:  0.921415722347
# epoch  1 , iteration  18500
#  current average loss:  0.976564690557
# epoch  1 , iteration  18750
#  current average loss:  1.08052345661
# epoch  1 , iteration  19000
#  current average loss:  1.27856352873
# epoch  1 , iteration  19250
#  current average loss:  0.548063953063
# epoch  1 , iteration  19500
#  current average loss:  1.66610819843
# epoch  1 , iteration  19750
#  current average loss:  0.839342405155
# epoch  1 , iteration  20000
#  current average loss:  0.200062175674
# evaluating..
#   Labeled   attachment score: 81 / 167 * 100 = 48.50 %
#   Unlabeled attachment score: 97 / 167 * 100 = 58.08 %
#   Label accuracy score:       104 / 167 * 100 = 62.28 %
#
# saving model with name tf_models/model-1-20000
# epoch  1 , iteration  20250
#  current average loss:  0.744442758366
# epoch  1 , iteration  20500
#  current average loss:  0.240243975206
# epoch  1 , iteration  20750
#  current average loss:  0.574523825191
# epoch  1 , iteration  21000
#  current average loss:  1.0454280456
# epoch  1 , iteration  21250
#  current average loss:  0.995329545928
# epoch  1 , iteration  21500
#  current average loss:  1.21614217834
# epoch  1 , iteration  21750
#  current average loss:  1.29944327945
# epoch  1 , iteration  22000
#  current average loss:  0.875726054788
# epoch  1 , iteration  22250
#  current average loss:  1.24529624763
# epoch  1 , iteration  22500
#  current average loss:  0.582789844049
# evaluating..
#   Labeled   attachment score: 79 / 167 * 100 = 47.31 %
#   Unlabeled attachment score: 94 / 167 * 100 = 56.29 %
#   Label accuracy score:       105 / 167 * 100 = 62.87 %
#
# epoch  1 , iteration  22750
#  current average loss:  0.903726615436
# epoch  1 , iteration  23000
#  current average loss:  0.830972982609
# epoch  1 , iteration  23250
#  current average loss:  0.625280716691
# epoch  1 , iteration  23500
#  current average loss:  0.878312186503
# epoch  1 , iteration  23750
#  current average loss:  1.03128481249
# epoch  1 , iteration  24000
#  current average loss:  0.606003803836
# epoch  1 , iteration  24250
#  current average loss:  0.787696149486
# epoch  1 , iteration  24500
#  current average loss:  0.32723439179
# epoch  1 , iteration  24750
#  current average loss:  1.09841512509
# epoch  1 , iteration  25000
#  current average loss:  1.13027235271
# evaluating..
#   Labeled   attachment score: 78 / 167 * 100 = 46.71 %
#   Unlabeled attachment score: 99 / 167 * 100 = 59.28 %
#   Label accuracy score:       98 / 167 * 100 = 58.68 %
#
# saving model with name tf_models/model-1-25000
# epoch  1 , iteration  25250
#  current average loss:  0.581726271169
# epoch  1 , iteration  25500
#  current average loss:  0.498972968612
# epoch  1 , iteration  25750
#  current average loss:  0.961884318476
# epoch  1 , iteration  26000
#  current average loss:  1.25547605559
# epoch  1 , iteration  26250
#  current average loss:  1.1299030075
# epoch  1 , iteration  26500
#  current average loss:  0.483981086323
# epoch  1 , iteration  26750
#  current average loss:  0.866219832682
# epoch  1 , iteration  27000
#  current average loss:  0.870757465462
# epoch  1 , iteration  27250
#  current average loss:  0.0828218669833
# epoch  1 , iteration  27500
#  current average loss:  0.898682702055
# evaluating..
#   Labeled   attachment score: 80 / 167 * 100 = 47.90 %
#   Unlabeled attachment score: 93 / 167 * 100 = 55.69 %
#   Label accuracy score:       113 / 167 * 100 = 67.66 %
#
# epoch  1 , iteration  27750
#  current average loss:  0.662178376806
# epoch  1 , iteration  28000
#  current average loss:  1.13071031539
# epoch  1 , iteration  28250
#  current average loss:  1.1152779099
# epoch  1 , iteration  28500
#  current average loss:  0.568653365391
# epoch  1 , iteration  28750
#  current average loss:  1.11943520739
# epoch  1 , iteration  29000
#  current average loss:  1.50943690592
# epoch  1 , iteration  29250
#  current average loss:  1.32194890946
# epoch  1 , iteration  29500
#  current average loss:  0.468590121269
# epoch  1 , iteration  29750
#  current average loss:  0.720705275615
# epoch  1 , iteration  30000
#  current average loss:  0.587667147185
# evaluating..
#   Labeled   attachment score: 79 / 167 * 100 = 47.31 %
#   Unlabeled attachment score: 94 / 167 * 100 = 56.29 %
#   Label accuracy score:       106 / 167 * 100 = 63.47 %
#
# saving model with name tf_models/model-1-30000
# epoch  1 , iteration  30250
#  current average loss:  0.961145839189
# epoch  1 , iteration  30500
#  current average loss:  1.07044243644
# epoch  1 , iteration  30750
#  current average loss:  0.616789166848
# epoch  1 , iteration  31000
#  current average loss:  0.547661368372
# epoch  1 , iteration  31250
#  current average loss:  0.815336636159
# epoch  1 , iteration  31500
#  current average loss:  1.15958303319
# epoch  1 , iteration  31750
#  current average loss:  0.383354807172
# epoch  1 , iteration  32000
#  current average loss:  1.06109126782
# epoch  1 , iteration  32250
#  current average loss:  0.537213424782
# epoch  1 , iteration  32500
#  current average loss:  0.633491503283
# evaluating..
#   Labeled   attachment score: 84 / 167 * 100 = 50.30 %
#   Unlabeled attachment score: 101 / 167 * 100 = 60.48 %
#   Label accuracy score:       109 / 167 * 100 = 65.27 %
#
# epoch  1 , iteration  32750
#  current average loss:  1.01860914405
# epoch  1 , iteration  33000
#  current average loss:  0.675739615436
# epoch  1 , iteration  33250
#  current average loss:  0.804555923198
# epoch  1 , iteration  33500
#  current average loss:  0.761968159816
# epoch  1 , iteration  33750
#  current average loss:  0.834905019931
# epoch  1 , iteration  34000
#  current average loss:  0.594218923339
# epoch  1 , iteration  34250
#  current average loss:  0.799389863342
# epoch  1 , iteration  34500
#  current average loss:  0.623460981519
# epoch  1 , iteration  34750
#  current average loss:  0.809468619939
# epoch  1 , iteration  35000
#  current average loss:  0.792857674138
# evaluating..
#   Labeled   attachment score: 92 / 167 * 100 = 55.09 %
#   Unlabeled attachment score: 104 / 167 * 100 = 62.28 %
#   Label accuracy score:       116 / 167 * 100 = 69.46 %
#
# saving model with name tf_models/model-1-35000
# epoch  1 , iteration  35250
#  current average loss:  1.5421341287
# epoch  1 , iteration  35500
#  current average loss:  1.16059652446
# epoch  1 , iteration  35750
#  current average loss:  1.72936575222
# epoch  1 , iteration  36000
#  current average loss:  0.456081935946
# epoch  1 , iteration  36250
#  current average loss:  0.730185984329
# epoch  1 , iteration  36500
#  current average loss:  0.7220639509
# epoch  1 , iteration  36750
#  current average loss:  0.688980068701
# epoch  1 , iteration  37000
#  current average loss:  1.11917276147
# epoch  1 , iteration  37250
#  current average loss:  0.823122839995
# epoch  1 , iteration  37500
#  current average loss:  1.75666463789
# evaluating..
#   Labeled   attachment score: 90 / 167 * 100 = 53.89 %
#   Unlabeled attachment score: 105 / 167 * 100 = 62.87 %
#   Label accuracy score:       113 / 167 * 100 = 67.66 %
#
# epoch  1 , iteration  37750
#  current average loss:  0.813165803083
# epoch  1 , iteration  38000
#  current average loss:  1.08216086855
# epoch  1 , iteration  38250
#  current average loss:  0.949186106789
# epoch  1 , iteration  38500
#  current average loss:  0.901038284191
# epoch  1 , iteration  38750
#  current average loss:  0.536205864777
# epoch  1 , iteration  39000
#  current average loss:  1.1369652837
# epoch  1 , iteration  39250
#  current average loss:  0.59900590133
# epoch  1 , iteration  39500
#  current average loss:  0.50032805984
# epoch  1 , iteration  39750
#  current average loss:  0.473974056076
# epoch  2 , iteration  0
#  current average loss:  0.813135630087
# evaluating..
#   Labeled   attachment score: 84 / 167 * 100 = 50.30 %
#   Unlabeled attachment score: 98 / 167 * 100 = 58.68 %
#   Label accuracy score:       117 / 167 * 100 = 70.06 %
#
# saving model with name tf_models/model-2-0
# epoch  2 , iteration  250
#  current average loss:  0.891106068297
# epoch  2 , iteration  500
#  current average loss:  0.706440299611
# epoch  2 , iteration  750
#  current average loss:  0.910235598315
# epoch  2 , iteration  1000
#  current average loss:  0.528485696563
# epoch  2 , iteration  1250
#  current average loss:  0.781479359251
# epoch  2 , iteration  1500
#  current average loss:  0.54603970073
# epoch  2 , iteration  1750
#  current average loss:  0.296851261602
# epoch  2 , iteration  2000
#  current average loss:  1.08200122373
# epoch  2 , iteration  2250
#  current average loss:  0.517743635625
# epoch  2 , iteration  2500
#  current average loss:  1.15309945275
# evaluating..
#   Labeled   attachment score: 90 / 167 * 100 = 53.89 %
#   Unlabeled attachment score: 102 / 167 * 100 = 61.08 %
#   Label accuracy score:       111 / 167 * 100 = 66.47 %
#
# epoch  2 , iteration  2750
#  current average loss:  1.11964691512
# epoch  2 , iteration  3000
#  current average loss:  0.76909106566
# epoch  2 , iteration  3250
#  current average loss:  0.695403991366
# epoch  2 , iteration  3500
#  current average loss:  0.64304569738
# epoch  2 , iteration  3750
#  current average loss:  1.1077788162
# epoch  2 , iteration  4000
#  current average loss:  1.02011107209
# epoch  2 , iteration  4250
#  current average loss:  1.1953369875
# epoch  2 , iteration  4500
#  current average loss:  0.953601788485
# epoch  2 , iteration  4750
#  current average loss:  0.80380339722
# epoch  2 , iteration  5000
#  current average loss:  0.970931233175
# evaluating..
#   Labeled   attachment score: 83 / 167 * 100 = 49.70 %
#   Unlabeled attachment score: 101 / 167 * 100 = 60.48 %
#   Label accuracy score:       109 / 167 * 100 = 65.27 %
#
# saving model with name tf_models/model-2-5000
# epoch  2 , iteration  5250
#  current average loss:  0.628875974058
# epoch  2 , iteration  5500
#  current average loss:  0.747394732903
# epoch  2 , iteration  5750
#  current average loss:  1.32926894881
# epoch  2 , iteration  6000
#  current average loss:  0.473748501771
# epoch  2 , iteration  6250
#  current average loss:  0.836318160663
# epoch  2 , iteration  6500
#  current average loss:  0.494145719033
# epoch  2 , iteration  6750
#  current average loss:  0.691498263059
# epoch  2 , iteration  7000
#  current average loss:  0.58060559314
# epoch  2 , iteration  7250
#  current average loss:  1.01887601247
# epoch  2 , iteration  7500
#  current average loss:  0.583660677598
# evaluating..
#   Labeled   attachment score: 94 / 167 * 100 = 56.29 %
#   Unlabeled attachment score: 107 / 167 * 100 = 64.07 %
#   Label accuracy score:       115 / 167 * 100 = 68.86 %
#
# epoch  2 , iteration  7750
#  current average loss:  1.33103761828
# epoch  2 , iteration  8000
#  current average loss:  0.569928984235
# epoch  2 , iteration  8250
#  current average loss:  0.44945274724
# epoch  2 , iteration  8500
#  current average loss:  1.39876463305
# epoch  2 , iteration  8750
#  current average loss:  0.595629963449
# epoch  2 , iteration  9000
#  current average loss:  0.482624869519
# epoch  2 , iteration  9250
#  current average loss:  0.824987317903
# epoch  2 , iteration  9500
#  current average loss:  0.798612231097
# epoch  2 , iteration  9750
#  current average loss:  0.19654641783
# epoch  2 , iteration  10000
#  current average loss:  0.444284594262
# evaluating..
#   Labeled   attachment score: 81 / 167 * 100 = 48.50 %
#   Unlabeled attachment score: 94 / 167 * 100 = 56.29 %
#   Label accuracy score:       107 / 167 * 100 = 64.07 %
#
# saving model with name tf_models/model-2-10000
# epoch  2 , iteration  10250
#  current average loss:  0.835550917627
# epoch  2 , iteration  10500
#  current average loss:  0.68207999327
# epoch  2 , iteration  10750
#  current average loss:  0.753916605176
# epoch  2 , iteration  11000
#  current average loss:  1.25310516904
# epoch  2 , iteration  11250
#  current average loss:  0.420319330982
# epoch  2 , iteration  11500
#  current average loss:  0.62540820228
# epoch  2 , iteration  11750
#  current average loss:  0.623883746704
# epoch  2 , iteration  12000
#  current average loss:  0.591161741819
# epoch  2 , iteration  12250
#  current average loss:  0.769072970528
# epoch  2 , iteration  12500
#  current average loss:  0.586477329997
# evaluating..
#   Labeled   attachment score: 82 / 167 * 100 = 49.10 %
#   Unlabeled attachment score: 99 / 167 * 100 = 59.28 %
#   Label accuracy score:       107 / 167 * 100 = 64.07 %
#
# epoch  2 , iteration  12750
#  current average loss:  0.720795621928
# epoch  2 , iteration  13000
#  current average loss:  0.208129179083
# epoch  2 , iteration  13250
#  current average loss:  0.945518451265
# epoch  2 , iteration  13500
#  current average loss:  0.761463441286
# epoch  2 , iteration  13750
#  current average loss:  0.767879410478
# epoch  2 , iteration  14000
#  current average loss:  1.26328793428
# epoch  2 , iteration  14250
#  current average loss:  1.41602805523
# epoch  2 , iteration  14500
#  current average loss:  0.942519019997
# epoch  2 , iteration  14750
#  current average loss:  0.282707194083
# epoch  2 , iteration  15000
#  current average loss:  1.27960165943
# evaluating..
#   Labeled   attachment score: 93 / 167 * 100 = 55.69 %
#   Unlabeled attachment score: 107 / 167 * 100 = 64.07 %
#   Label accuracy score:       117 / 167 * 100 = 70.06 %
#
# saving model with name tf_models/model-2-15000
# epoch  2 , iteration  15250
#  current average loss:  0.740557518133
# epoch  2 , iteration  15500
#  current average loss:  0.949031824096
# epoch  2 , iteration  15750
#  current average loss:  0.801921731346
# epoch  2 , iteration  16000
#  current average loss:  0.568729013613
# epoch  2 , iteration  16250
#  current average loss:  0.652608464394
# epoch  2 , iteration  16500
#  current average loss:  0.91739018909
# epoch  2 , iteration  16750
#  current average loss:  1.33888150935
# epoch  2 , iteration  17000
#  current average loss:  0.64022968009
# epoch  2 , iteration  17250
#  current average loss:  0.577155521198
# epoch  2 , iteration  17500
#  current average loss:  0.901099502507
# evaluating..
#   Labeled   attachment score: 102 / 167 * 100 = 61.08 %
#   Unlabeled attachment score: 112 / 167 * 100 = 67.07 %
#   Label accuracy score:       125 / 167 * 100 = 74.85 %
#
# epoch  2 , iteration  17750
#  current average loss:  0.765719515696
# epoch  2 , iteration  18000
#  current average loss:  0.263307553603
# epoch  2 , iteration  18250
#  current average loss:  0.56588103648
# epoch  2 , iteration  18500
#  current average loss:  0.817340524738
# epoch  2 , iteration  18750
#  current average loss:  1.09354377034
# epoch  2 , iteration  19000
#  current average loss:  0.973756020526
# epoch  2 , iteration  19250
#  current average loss:  0.368146052145
# epoch  2 , iteration  19500
#  current average loss:  1.44083818583
# epoch  2 , iteration  19750
#  current average loss:  0.681367686153
# epoch  2 , iteration  20000
#  current average loss:  0.264600340863
# evaluating..
#   Labeled   attachment score: 92 / 167 * 100 = 55.09 %
#   Unlabeled attachment score: 106 / 167 * 100 = 63.47 %
#   Label accuracy score:       115 / 167 * 100 = 68.86 %
#
# saving model with name tf_models/model-2-20000
# epoch  2 , iteration  20250
#  current average loss:  0.61241244756
# epoch  2 , iteration  20500
#  current average loss:  0.0954745379874
# epoch  2 , iteration  20750
#  current average loss:  0.515450487533
# epoch  2 , iteration  21000
#  current average loss:  0.750858984338
# epoch  2 , iteration  21250
#  current average loss:  0.838028914979
# epoch  2 , iteration  21500
#  current average loss:  0.825921420682
# epoch  2 , iteration  21750
#  current average loss:  1.08018846648
# epoch  2 , iteration  22000
#  current average loss:  0.764373186434
# epoch  2 , iteration  22250
#  current average loss:  1.14007104089
# epoch  2 , iteration  22500
#  current average loss:  0.482397418789
# evaluating..
#   Labeled   attachment score: 82 / 167 * 100 = 49.10 %
#   Unlabeled attachment score: 100 / 167 * 100 = 59.88 %
#   Label accuracy score:       108 / 167 * 100 = 64.67 %
#
# epoch  2 , iteration  22750
#  current average loss:  0.865227479517
# epoch  2 , iteration  23000
#  current average loss:  0.518513414917
# epoch  2 , iteration  23250
#  current average loss:  0.358120418224
# epoch  2 , iteration  23500
#  current average loss:  0.641492928212
# epoch  2 , iteration  23750
#  current average loss:  1.10729264789
# epoch  2 , iteration  24000
#  current average loss:  0.566725324526
# epoch  2 , iteration  24250
#  current average loss:  0.554163353781
# epoch  2 , iteration  24500
#  current average loss:  0.0868398415301
# epoch  2 , iteration  24750
#  current average loss:  0.898989914278
# epoch  2 , iteration  25000
#  current average loss:  0.86048580206
# evaluating..
#   Labeled   attachment score: 93 / 167 * 100 = 55.69 %
#   Unlabeled attachment score: 107 / 167 * 100 = 64.07 %
#   Label accuracy score:       114 / 167 * 100 = 68.26 %
#
# saving model with name tf_models/model-2-25000
# epoch  2 , iteration  25250
#  current average loss:  0.48893362147
# epoch  2 , iteration  25500
#  current average loss:  0.406449397674
# epoch  2 , iteration  25750
#  current average loss:  0.725807737117
# epoch  2 , iteration  26000
#  current average loss:  0.920107526698
# epoch  2 , iteration  26250
#  current average loss:  0.844592544616
# epoch  2 , iteration  26500
#  current average loss:  0.356626566202
# epoch  2 , iteration  26750
#  current average loss:  0.775969652773
# epoch  2 , iteration  27000
#  current average loss:  0.619873118194
# epoch  2 , iteration  27250
#  current average loss:  0.143275028763
# epoch  2 , iteration  27500
#  current average loss:  0.895119206774
# evaluating..
#   Labeled   attachment score: 85 / 167 * 100 = 50.90 %
#   Unlabeled attachment score: 97 / 167 * 100 = 58.08 %
#   Label accuracy score:       117 / 167 * 100 = 70.06 %
#
# epoch  2 , iteration  27750
#  current average loss:  0.386375183596
# epoch  2 , iteration  28000
#  current average loss:  0.893977944383
# epoch  2 , iteration  28250
#  current average loss:  1.06109873703
# epoch  2 , iteration  28500
#  current average loss:  0.593140843367
# epoch  2 , iteration  28750
#  current average loss:  0.959606508232
# epoch  2 , iteration  29000
#  current average loss:  1.27597190463
# epoch  2 , iteration  29250
#  current average loss:  0.95305997017
# epoch  2 , iteration  29500
#  current average loss:  0.375089798663
# epoch  2 , iteration  29750
#  current average loss:  0.628419516848
# epoch  2 , iteration  30000
#  current average loss:  0.363404918049
# evaluating..
#   Labeled   attachment score: 92 / 167 * 100 = 55.09 %
#   Unlabeled attachment score: 105 / 167 * 100 = 62.87 %
#   Label accuracy score:       120 / 167 * 100 = 71.86 %
#
# saving model with name tf_models/model-2-30000
# epoch  2 , iteration  30250
#  current average loss:  0.840026792822
# epoch  2 , iteration  30500
#  current average loss:  0.78718149858
# epoch  2 , iteration  30750
#  current average loss:  0.202076797578
# epoch  2 , iteration  31000
#  current average loss:  0.343896713485
# epoch  2 , iteration  31250
#  current average loss:  0.782470130564
# epoch  2 , iteration  31500
#  current average loss:  0.713729610456
# epoch  2 , iteration  31750
#  current average loss:  0.194090492985
# epoch  2 , iteration  32000
#  current average loss:  1.00746323583
# epoch  2 , iteration  32250
#  current average loss:  0.686372685034
# epoch  2 , iteration  32500
#  current average loss:  0.405577104227
# evaluating..
#   Labeled   attachment score: 95 / 167 * 100 = 56.89 %
#   Unlabeled attachment score: 110 / 167 * 100 = 65.87 %
#   Label accuracy score:       113 / 167 * 100 = 67.66 %
#
# epoch  2 , iteration  32750
#  current average loss:  0.844910736765
# epoch  2 , iteration  33000
#  current average loss:  0.589948474541
# epoch  2 , iteration  33250
#  current average loss:  0.630408603847
# epoch  2 , iteration  33500
#  current average loss:  0.606961706508
# epoch  2 , iteration  33750
#  current average loss:  0.642453246656
# epoch  2 , iteration  34000
#  current average loss:  0.394625549086
# epoch  2 , iteration  34250
#  current average loss:  0.565248532083
# epoch  2 , iteration  34500
#  current average loss:  0.574403502313
# epoch  2 , iteration  34750
#  current average loss:  0.523135153574
# epoch  2 , iteration  35000
#  current average loss:  0.8699385139
# evaluating..
#   Labeled   attachment score: 94 / 167 * 100 = 56.29 %
#   Unlabeled attachment score: 113 / 167 * 100 = 67.66 %
#   Label accuracy score:       111 / 167 * 100 = 66.47 %
#
# saving model with name tf_models/model-2-35000
# epoch  2 , iteration  35250
#  current average loss:  1.17491689971
# epoch  2 , iteration  35500
#  current average loss:  0.732895090163
# epoch  2 , iteration  35750
#  current average loss:  1.26992012014
# epoch  2 , iteration  36000
#  current average loss:  0.373794373119
# epoch  2 , iteration  36250
#  current average loss:  0.812632729035
# epoch  2 , iteration  36500
#  current average loss:  0.554811330609
# epoch  2 , iteration  36750
#  current average loss:  0.667395305356
# epoch  2 , iteration  37000
#  current average loss:  0.840927072854
# epoch  2 , iteration  37250
#  current average loss:  0.633494056171
# epoch  2 , iteration  37500
#  current average loss:  1.6462364411
# evaluating..
#   Labeled   attachment score: 95 / 167 * 100 = 56.89 %
#   Unlabeled attachment score: 111 / 167 * 100 = 66.47 %
#   Label accuracy score:       117 / 167 * 100 = 70.06 %
#
# epoch  2 , iteration  37750
#  current average loss:  0.974344360764
# epoch  2 , iteration  38000
#  current average loss:  0.853567926488
# epoch  2 , iteration  38250
#  current average loss:  0.723198971275
# epoch  2 , iteration  38500
#  current average loss:  0.453707337105
# epoch  2 , iteration  38750
#  current average loss:  0.427532578472
# epoch  2 , iteration  39000
#  current average loss:  1.08278628789
# epoch  2 , iteration  39250
#  current average loss:  0.75143929342
# epoch  2 , iteration  39500
#  current average loss:  0.354086296395
# epoch  2 , iteration  39750
#  current average loss:  0.421698782258
# epoch  3 , iteration  0
#  current average loss:  0.738244562141
# evaluating..
#   Labeled   attachment score: 101 / 167 * 100 = 60.48 %
#   Unlabeled attachment score: 115 / 167 * 100 = 68.86 %
#   Label accuracy score:       121 / 167 * 100 = 72.46 %
#
# saving model with name tf_models/model-3-0
# epoch  3 , iteration  250
#  current average loss:  0.603947111987
# epoch  3 , iteration  500
#  current average loss:  0.674644911542
# epoch  3 , iteration  750
#  current average loss:  0.794531836505
# epoch  3 , iteration  1000
#  current average loss:  0.716632974353
# epoch  3 , iteration  1250
#  current average loss:  0.738149639746
# epoch  3 , iteration  1500
#  current average loss:  0.525851337149
# epoch  3 , iteration  1750
#  current average loss:  0.302255204684
# epoch  3 , iteration  2000
#  current average loss:  1.24534176227
# epoch  3 , iteration  2250
#  current average loss:  0.487387790184
# epoch  3 , iteration  2500
#  current average loss:  1.05687540867
# evaluating..
#   Labeled   attachment score: 89 / 167 * 100 = 53.29 %
#   Unlabeled attachment score: 104 / 167 * 100 = 62.28 %
#   Label accuracy score:       116 / 167 * 100 = 69.46 %
#
# epoch  3 , iteration  2750
#  current average loss:  1.14481012124
# epoch  3 , iteration  3000
#  current average loss:  0.656981765086
# epoch  3 , iteration  3250
#  current average loss:  0.653576667245
# epoch  3 , iteration  3500
#  current average loss:  0.501994316483
# epoch  3 , iteration  3750
#  current average loss:  0.521058914456
# epoch  3 , iteration  4000
#  current average loss:  0.740226810898
# epoch  3 , iteration  4250
#  current average loss:  1.27297606383
# epoch  3 , iteration  4500
#  current average loss:  0.41849945693
# epoch  3 , iteration  4750
#  current average loss:  1.05343751032
# epoch  3 , iteration  5000
#  current average loss:  0.768495746615
# evaluating..
#   Labeled   attachment score: 101 / 167 * 100 = 60.48 %
#   Unlabeled attachment score: 116 / 167 * 100 = 69.46 %
#   Label accuracy score:       123 / 167 * 100 = 73.65 %
#
# saving model with name tf_models/model-3-5000
# epoch  3 , iteration  5250
#  current average loss:  0.570493202583
# epoch  3 , iteration  5500
#  current average loss:  0.573262170899
# epoch  3 , iteration  5750
#  current average loss:  0.968574904547
# epoch  3 , iteration  6000
#  current average loss:  0.442466655114
# epoch  3 , iteration  6250
#  current average loss:  0.672798988922
# epoch  3 , iteration  6500
#  current average loss:  0.268849417325
# epoch  3 , iteration  6750
#  current average loss:  0.748367175515
# epoch  3 , iteration  7000
#  current average loss:  0.928465683694
# epoch  3 , iteration  7250
#  current average loss:  0.779166672069
# epoch  3 , iteration  7500
#  current average loss:  0.579140412554
# evaluating..
#   Labeled   attachment score: 92 / 167 * 100 = 55.09 %
#   Unlabeled attachment score: 105 / 167 * 100 = 62.87 %
#   Label accuracy score:       123 / 167 * 100 = 73.65 %
#
# epoch  3 , iteration  7750
#  current average loss:  1.93084726348
# epoch  3 , iteration  8000
#  current average loss:  0.452654554097
# epoch  3 , iteration  8250
#  current average loss:  0.362358075556
# epoch  3 , iteration  8500
#  current average loss:  1.30610630974
# epoch  3 , iteration  8750
#  current average loss:  0.639343314517
# epoch  3 , iteration  9000
#  current average loss:  0.215402627741
# epoch  3 , iteration  9250
#  current average loss:  0.741697689494
# epoch  3 , iteration  9500
#  current average loss:  1.0071676545
# epoch  3 , iteration  9750
#  current average loss:  0.0764488434534
# epoch  3 , iteration  10000
#  current average loss:  0.318412566301
# evaluating..
#   Labeled   attachment score: 96 / 167 * 100 = 57.49 %
#   Unlabeled attachment score: 110 / 167 * 100 = 65.87 %
#   Label accuracy score:       118 / 167 * 100 = 70.66 %
#
# saving model with name tf_models/model-3-10000
# epoch  3 , iteration  10250
#  current average loss:  0.649603188356
# epoch  3 , iteration  10500
#  current average loss:  0.569810045587
# epoch  3 , iteration  10750
#  current average loss:  0.765388034725
# epoch  3 , iteration  11000
#  current average loss:  1.00177549894
# epoch  3 , iteration  11250
#  current average loss:  0.278926546886
# epoch  3 , iteration  11500
#  current average loss:  0.64408308685
# epoch  3 , iteration  11750
#  current average loss:  0.701390796427
# epoch  3 , iteration  12000
#  current average loss:  0.333473784043
# epoch  3 , iteration  12250
#  current average loss:  0.562794620925
# epoch  3 , iteration  12500
#  current average loss:  0.3838254409
# evaluating..
#   Labeled   attachment score: 98 / 167 * 100 = 58.68 %
#   Unlabeled attachment score: 113 / 167 * 100 = 67.66 %
#   Label accuracy score:       122 / 167 * 100 = 73.05 %
#
# epoch  3 , iteration  12750
#  current average loss:  0.647803802534
# epoch  3 , iteration  13000
#  current average loss:  0.24877012724
# epoch  3 , iteration  13250
#  current average loss:  0.914577945847
# epoch  3 , iteration  13500
#  current average loss:  0.957393611822
# epoch  3 , iteration  13750
#  current average loss:  0.411934234026
# epoch  3 , iteration  14000
#  current average loss:  1.3523771786
# epoch  3 , iteration  14250
#  current average loss:  1.13743435437
# epoch  3 , iteration  14500
#  current average loss:  0.806113594374
# epoch  3 , iteration  14750
#  current average loss:  0.25655089787
# epoch  3 , iteration  15000
#  current average loss:  1.09870791966
# evaluating..
#   Labeled   attachment score: 91 / 167 * 100 = 54.49 %
#   Unlabeled attachment score: 107 / 167 * 100 = 64.07 %
#   Label accuracy score:       116 / 167 * 100 = 69.46 %
#
# saving model with name tf_models/model-3-15000
# epoch  3 , iteration  15250
#  current average loss:  0.822727868508
# epoch  3 , iteration  15500
#  current average loss:  0.712894608823
# epoch  3 , iteration  15750
#  current average loss:  0.809904555067
# epoch  3 , iteration  16000
# ...
#
# epoch  7 , iteration  32750
#  current average loss:  0.512029990834
# epoch  7 , iteration  33000
#  current average loss:  0.250642947693
# epoch  7 , iteration  33250
#  current average loss:  0.309865304113
# epoch  7 , iteration  33500
#  current average loss:  0.410825000921
# epoch  7 , iteration  33750
#  current average loss:  0.41705962001
# epoch  7 , iteration  34000
#  current average loss:  0.496789731439
# epoch  7 , iteration  34250
#  current average loss:  0.409756916787
# epoch  7 , iteration  34500
#  current average loss:  0.475020911006
# epoch  7 , iteration  34750
#  current average loss:  0.455804738833
# epoch  7 , iteration  35000
#  current average loss:  0.379639080828
# evaluating..
#   Labeled   attachment score: 103 / 167 * 100 = 61.68 %
#   Unlabeled attachment score: 114 / 167 * 100 = 68.26 %
#   Label accuracy score:       122 / 167 * 100 = 73.05 %
#
# saving model with name tf_models/model-7-35000
# epoch  7 , iteration  35250
#  current average loss:  0.95989068622
# epoch  7 , iteration  35500
#  current average loss:  0.320352879258
# epoch  7 , iteration  35750
#  current average loss:  0.999475432603
# epoch  7 , iteration  36000
#  current average loss:  0.218078212003
# epoch  7 , iteration  36250
#  current average loss:  0.524917616128
# epoch  7 , iteration  36500
#  current average loss:  0.527906202743
# epoch  7 , iteration  36750
#  current average loss:  0.347722496925
# epoch  7 , iteration  37000
#  current average loss:  0.584967873336
# epoch  7 , iteration  37250
#  current average loss:  0.503391695131
# epoch  7 , iteration  37500
#  current average loss:  1.58426107222
# evaluating..
#   Labeled   attachment score: 108 / 167 * 100 = 64.67 %
#   Unlabeled attachment score: 121 / 167 * 100 = 72.46 %
#   Label accuracy score:       127 / 167 * 100 = 76.05 %
#
# epoch  7 , iteration  37750
#  current average loss:  0.484786706958
# epoch  7 , iteration  38000
#  current average loss:  0.503716784203
# epoch  7 , iteration  38250
#  current average loss:  0.418573698186
# epoch  7 , iteration  38500
#  current average loss:  0.17160994631
# epoch  7 , iteration  38750
#  current average loss:  0.178807975636
# epoch  7 , iteration  39000
#  current average loss:  0.67713322884
# epoch  7 , iteration  39250
#  current average loss:  0.545949845102
# epoch  7 , iteration  39500
#  current average loss:  0.233874086173
# epoch  7 , iteration  39750
#  current average loss:  0.282752510399
# epoch  8 , iteration  0
#  current average loss:  0.525761967819
# evaluating..
#   Labeled   attachment score: 107 / 167 * 100 = 64.07 %
#   Unlabeled attachment score: 115 / 167 * 100 = 68.86 %
#   Label accuracy score:       128 / 167 * 100 = 76.65 %
#
# saving model with name tf_models/model-8-0
# epoch  8 , iteration  250
#  current average loss:  0.449925027286
# epoch  8 , iteration  500
#  current average loss:  0.373158955207
# epoch  8 , iteration  750
#  current average loss:  0.601617698863
# epoch  8 , iteration  1000
#  current average loss:  0.505261816332
# epoch  8 , iteration  1250
#  current average loss:  0.486282439366
# epoch  8 , iteration  1500
#  current average loss:  0.338547024584
# epoch  8 , iteration  1750
#  current average loss:  0.218724099266
# epoch  8 , iteration  2000
#  current average loss:  0.983458241546
# epoch  8 , iteration  2250
#  current average loss:  0.239953704352
# epoch  8 , iteration  2500
#  current average loss:  0.738230631043
# evaluating..
#   Labeled   attachment score: 104 / 167 * 100 = 62.28 %
#   Unlabeled attachment score: 116 / 167 * 100 = 69.46 %
#   Label accuracy score:       126 / 167 * 100 = 75.45 %
#
# epoch  8 , iteration  2750
#  current average loss:  0.74617497416
# epoch  8 , iteration  3000
#  current average loss:  0.592729854429
# epoch  8 , iteration  3250
#  current average loss:  0.308712542606
# epoch  8 , iteration  3500
#  current average loss:  0.510541003056
# epoch  8 , iteration  3750
#  current average loss:  0.746042603941
# epoch  8 , iteration  4000
#  current average loss:  0.638530617971
# epoch  8 , iteration  4250
#  current average loss:  0.790393835945
# epoch  8 , iteration  4500
#  current average loss:  0.381360136265
# epoch  8 , iteration  4750
#  current average loss:  0.638439400488
# epoch  8 , iteration  5000
#  current average loss:  0.345036367252
# evaluating..
#   Labeled   attachment score: 107 / 167 * 100 = 64.07 %
#   Unlabeled attachment score: 118 / 167 * 100 = 70.66 %
#   Label accuracy score:       134 / 167 * 100 = 80.24 %
#
# saving model with name tf_models/model-8-5000
# epoch  8 , iteration  5250
#  current average loss:  0.404856696975
# epoch  8 , iteration  5500
#  current average loss:  0.314450188917
# epoch  8 , iteration  5750
#  current average loss:  0.782280381593
# epoch  8 , iteration  6000
#  current average loss:  0.320013790374
# epoch  8 , iteration  6250
#  current average loss:  0.384112124949
# epoch  8 , iteration  6500
#  current average loss:  0.246142674496
# epoch  8 , iteration  6750
#  current average loss:  0.485594352374
# epoch  8 , iteration  7000
#  current average loss:  0.491686110393
# epoch  8 , iteration  7250
#  current average loss:  0.612251727428
# epoch  8 , iteration  7500
#  current average loss:  0.278995064762
# evaluating..
#   Labeled   attachment score: 116 / 167 * 100 = 69.46 %
#   Unlabeled attachment score: 129 / 167 * 100 = 77.25 %
#   Label accuracy score:       129 / 167 * 100 = 77.25 %
#
# epoch  8 , iteration  7750
#  current average loss:  0.766307362472
# epoch  8 , iteration  8000
#  current average loss:  0.335314412043
# epoch  8 , iteration  8250
#  current average loss:  0.15006597687
# epoch  8 , iteration  8500
#  current average loss:  0.852298215729
# epoch  8 , iteration  8750
#  current average loss:  0.312717442363
# epoch  8 , iteration  9000
#  current average loss:  0.171191839969
# epoch  8 , iteration  9250
#  current average loss:  0.507550415116
# epoch  8 , iteration  9500
#  current average loss:  0.397922801994
# epoch  8 , iteration  9750
#  current average loss:  0.120309347464
# epoch  8 , iteration  10000
#  current average loss:  0.154289092421
# evaluating..
#   Labeled   attachment score: 104 / 167 * 100 = 62.28 %
#   Unlabeled attachment score: 118 / 167 * 100 = 70.66 %
#   Label accuracy score:       129 / 167 * 100 = 77.25 %
#
# saving model with name tf_models/model-8-10000
# epoch  8 , iteration  10250
#  current average loss:  0.373769507047
# epoch  8 , iteration  10500
#  current average loss:  0.401453691996
# epoch  8 , iteration  10750
#  current average loss:  0.266808677887
# epoch  8 , iteration  11000
#  current average loss:  0.579628025119
# epoch  8 , iteration  11250
#  current average loss:  0.208360639812
# epoch  8 , iteration  11500
#  current average loss:  0.365771672978
# epoch  8 , iteration  11750
#  current average loss:  0.268451059867
# epoch  8 , iteration  12000
#  current average loss:  0.158856279387
# epoch  8 , iteration  12250
#  current average loss:  0.497156789996
# epoch  8 , iteration  12500
#  current average loss:  0.293215369148
# evaluating..
#   Labeled   attachment score: 108 / 167 * 100 = 64.67 %
#   Unlabeled attachment score: 118 / 167 * 100 = 70.66 %
#   Label accuracy score:       129 / 167 * 100 = 77.25 %
#
# epoch  8 , iteration  12750
#  current average loss:  0.469763316677
# epoch  8 , iteration  13000
#  current average loss:  0.155732271969
# epoch  8 , iteration  13250
#  current average loss:  0.541207992237
# epoch  8 , iteration  13500
#  current average loss:  0.612785497322
# epoch  8 , iteration  13750
#  current average loss:  0.399369528041
# epoch  8 , iteration  14000
#  current average loss:  0.621716363036
# epoch  8 , iteration  14250
#  current average loss:  1.59907188679
# epoch  8 , iteration  14500
#  current average loss:  0.522635115646
# epoch  8 , iteration  14750
#  current average loss:  0.158812590593
# epoch  8 , iteration  15000
#  current average loss:  1.1491051674
# evaluating..
#   Labeled   attachment score: 112 / 167 * 100 = 67.07 %
#   Unlabeled attachment score: 125 / 167 * 100 = 74.85 %
#   Label accuracy score:       132 / 167 * 100 = 79.04 %
#
# saving model with name tf_models/model-8-15000
# epoch  8 , iteration  15250
#  current average loss:  0.623839073496
# epoch  8 , iteration  15500
#  current average loss:  0.569335314338
# epoch  8 , iteration  15750
#  current average loss:  0.57820529271
# epoch  8 , iteration  16000
#  current average loss:  0.420764038964
# epoch  8 , iteration  16250
#  current average loss:  0.384395031474
# epoch  8 , iteration  16500
#  current average loss:  0.547709664864
# epoch  8 , iteration  16750
#  current average loss:  0.955963235302
# epoch  8 , iteration  17000
#  current average loss:  0.431654749906
# epoch  8 , iteration  17250
#  current average loss:  0.394206978861
# epoch  8 , iteration  17500
#  current average loss:  0.580069656247
# evaluating..
#   Labeled   attachment score: 106 / 167 * 100 = 63.47 %
#   Unlabeled attachment score: 118 / 167 * 100 = 70.66 %
#   Label accuracy score:       126 / 167 * 100 = 75.45 %
#
# epoch  8 , iteration  17750
#  current average loss:  0.359842884831
# epoch  8 , iteration  18000
#  current average loss:  0.116652910106
# epoch  8 , iteration  18250
#  current average loss:  0.536003673189
# epoch  8 , iteration  18500
#  current average loss:  0.139109786765
# epoch  8 , iteration  18750
#  current average loss:  0.591999341506
# epoch  8 , iteration  19000
#  current average loss:  0.499253410343
# epoch  8 , iteration  19250
#  current average loss:  0.321041670339
# epoch  8 , iteration  19500
#  current average loss:  1.17054983572
# epoch  8 , iteration  19750
#  current average loss:  0.407119359329
# epoch  8 , iteration  20000
#  current average loss:  0.126896640847
# evaluating..
#   Labeled   attachment score: 122 / 167 * 100 = 73.05 %
#   Unlabeled attachment score: 131 / 167 * 100 = 78.44 %
#   Label accuracy score:       137 / 167 * 100 = 82.04 %
#
# saving model with name tf_models/model-8-20000
# epoch  8 , iteration  20250
#  current average loss:  0.480231025501
# epoch  8 , iteration  20500
#  current average loss:  0.194875154126
# epoch  8 , iteration  20750
#  current average loss:  0.319484911486
# epoch  8 , iteration  21000
#  current average loss:  0.50797924577
# epoch  8 , iteration  21250
#  current average loss:  0.473834996163
# epoch  8 , iteration  21500
#  current average loss:  0.68222498249
# epoch  8 , iteration  21750
#  current average loss:  0.820155053549
# epoch  8 , iteration  22000
#  current average loss:  0.376643925836
# epoch  8 , iteration  22250
#  current average loss:  0.702465725423
# epoch  8 , iteration  22500
#  current average loss:  0.353863851328
# evaluating..
#   Labeled   attachment score: 112 / 167 * 100 = 67.07 %
#   Unlabeled attachment score: 126 / 167 * 100 = 75.45 %
#   Label accuracy score:       125 / 167 * 100 = 74.85 %
#
# epoch  8 , iteration  22750
#  current average loss:  0.673220186434
# epoch  8 , iteration  23000
#  current average loss:  0.41558554042
# epoch  8 , iteration  23250
#  current average loss:  0.153015389466
# epoch  8 , iteration  23500
#  current average loss:  0.76116618216
# epoch  8 , iteration  23750
#  current average loss:  0.452365702718
# epoch  8 , iteration  24000
#  current average loss:  0.486487978353
# epoch  8 , iteration  24250
#  current average loss:  0.46216679287
# epoch  8 , iteration  24500
#  current average loss:  0.0759505801153
# epoch  8 , iteration  24750
#  current average loss:  0.790364686906
# epoch  8 , iteration  25000
#  current average loss:  0.434212751935
# evaluating..
#   Labeled   attachment score: 109 / 167 * 100 = 65.27 %
#   Unlabeled attachment score: 124 / 167 * 100 = 74.25 %
#   Label accuracy score:       132 / 167 * 100 = 79.04 %
#
# saving model with name tf_models/model-8-25000
# epoch  8 , iteration  25250
#  current average loss:  0.300691360854
# epoch  8 , iteration  25500
#  current average loss:  0.231450672596
# epoch  8 , iteration  25750
#  current average loss:  0.444315590156
# epoch  8 , iteration  26000
#  current average loss:  0.400702644733
# epoch  8 , iteration  26250
#  current average loss:  0.370731496037
# epoch  8 , iteration  26500
#  current average loss:  0.200605262007
# epoch  8 , iteration  26750
#  current average loss:  0.655574427386
# epoch  8 , iteration  27000
#  current average loss:  0.541456614208
# epoch  8 , iteration  27250
#  current average loss:  0.174856063305
# epoch  8 , iteration  27500
#  current average loss:  0.603615994672
# evaluating..
#   Labeled   attachment score: 110 / 167 * 100 = 65.87 %
#   Unlabeled attachment score: 123 / 167 * 100 = 73.65 %
#   Label accuracy score:       126 / 167 * 100 = 75.45 %
#
# epoch  8 , iteration  27750
#  current average loss:  0.270327985246
# epoch  8 , iteration  28000
#  current average loss:  0.696427428703
# epoch  8 , iteration  28250
#  current average loss:  0.875741587272
# epoch  8 , iteration  28500
#  current average loss:  0.236344452307
# epoch  8 , iteration  28750
#  current average loss:  0.514040173094
# epoch  8 , iteration  29000
#  current average loss:  0.899671619873
# epoch  8 , iteration  29250
#  current average loss:  0.622613986617
# epoch  8 , iteration  29500
#  current average loss:  0.218101732028
# epoch  8 , iteration  29750
#  current average loss:  0.375211348897
# epoch  8 , iteration  30000
#  current average loss:  0.257012497173
# evaluating..
#   Labeled   attachment score: 114 / 167 * 100 = 68.26 %
#   Unlabeled attachment score: 125 / 167 * 100 = 74.85 %
#   Label accuracy score:       138 / 167 * 100 = 82.63 %
#
# saving model with name tf_models/model-8-30000
# epoch  8 , iteration  30250
#  current average loss:  0.525055673482
# epoch  8 , iteration  30500
#  current average loss:  0.564780236967
# epoch  8 , iteration  30750
#  current average loss:  0.122333229998
# epoch  8 , iteration  31000
#  current average loss:  0.467705993543
# epoch  8 , iteration  31250
#  current average loss:  0.505193275874
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-12d83fae6db8> in <module>()
#      94                 feed_dict_batch = {sentence_length: [seq_length], lstm_x: [sentence],  parse_indices: [indices], labels: actions}
#      95
# ---> 96                 result = session.run([train_op, cost_indication], feed_dict_batch)
#      97
#      98                 if i%250 == 0:
#
# /usr/lib/python3.4/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/lib/python3.4/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     913     if final_fetches or final_targets:
#     914       results = self._do_run(handle, final_targets, final_fetches,
# --> 915                              feed_dict_string, options, run_metadata)
#     916     else:
#     917       results = []
#
# /usr/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     963     if handle is None:
#     964       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 965                            target_list, options, run_metadata)
#     966     else:
#     967       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/lib/python3.4/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#     970   def _do_call(self, fn, *args):
#     971     try:
# --> 972       return fn(*args)
#     973     except errors.OpError as e:
#     974       message = compat.as_text(e.message)
#
# /usr/lib/python3.4/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     952         return tf_session.TF_Run(session, options,
#     953                                  feed_dict, fetch_list, target_list,
# --> 954                                  status, run_metadata)
#     955
#     956     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# TEST: should score 100% when file is compared to itself
val_output = subprocess.check_output(["perl", "eval.pl", "-g", "HOI.conll", "-s", "HOI.conll", "-q"])
print(val_output.decode("utf-8"))
# Out:
#   Labeled   attachment score: 167 / 167 * 100 = 100.00 %
#   Unlabeled attachment score: 167 / 167 * 100 = 100.00 %
#   Label accuracy score:       167 / 167 * 100 = 100.00 %

# %%
sess = tf.Session()
# get the model that was trained furthest. model-1-5000.meta means epoch 1, iter 5000
new_saver = tf.train.import_meta_graph('tf_models/model-0-400.meta')
new_saver.restore(sess, tf.train.latest_checkpoint('./'))
all_vars = tf.trainable_variables()
for v in all_vars:
    print(v.name)
# Out:
# weights_h:0
# weights_out:0
# biases_b:0
# biases_out:0
# BiRNN/FW/BasicLSTMCell/Linear/Matrix:0
# BiRNN/FW/BasicLSTMCell/Linear/Bias:0
# BiRNN/BW/BasicLSTMCell/Linear/Matrix:0
# BiRNN/BW/BasicLSTMCell/Linear/Bias:0
